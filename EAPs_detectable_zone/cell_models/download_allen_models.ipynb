# %%
import pandas as pd

# %%
data = pd.read_csv('cell_types_specimen_details.csv')
idxs = data["donor__species"] == "Mus musculus"

# %%
data[idxs]["m__biophys_perisomatic"] == 1
# Out:
# 1       False
# 2       False
# 4       False
# 6        True
# 7        True
#         ...
# 2327    False
# 2329    False
# 2330    False
# 2331    False
# 2332     True
# Name: m__biophys_perisomatic, Length: 1920, dtype: bool

# %%
mouse_data = data[data["donor__species"] == "Mus musculus" ]

# %%
mouse_data["csl__normalized_depth"]
# Out:
# 1       0.582057
# 2       0.469578
# 4            NaN
# 6       0.478344
# 7       0.608590
#           ...
# 2327    0.977622
# 2329    0.240614
# 2330    0.363275
# 2331         NaN
# 2332    0.767684
# Name: csl__normalized_depth, Length: 1920, dtype: float64

# %%
float(mouse_data[mouse_data.specimen__id == 386049446]["csl__normalized_depth"])
# Out:
# 0.369535013823174

# %%
mouse_data
# Out:
#                              line_name  specimen__id  \
# 1                         Oxtr-T2A-Cre     565871768
# 2                       Pvalb-IRES-Cre     469801138
# 4     Slc32a1-T2A-FlpO|Vipr2-IRES2-Cre     605889373
# 6                         Cux2-CreERT2     485909730
# 7                       Scnn1a-Tg3-Cre     323865917
# ...                                ...           ...
# 2327                    Ctgf-T2A-dgCre     512322162
# 2329                    Rorb-IRES2-Cre     488473535
# 2330                    Rorb-IRES2-Cre     467003163
# 2331                    Pvalb-IRES-Cre     572609946
# 2332                      Sst-IRES-Cre     464212183
#
#                                          specimen__name specimen__hemisphere  \
# 1                      Oxtr-2A-Cre;Ai14-293837.03.01.02                 left
# 2                   Pvalb-IRES-Cre;Ai14-170927.05.02.01                right
# 4     Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO;Ai65-337419.0...                right
# ...

# %%
data
# Out:
#                              line_name  specimen__id  \
# 0                                  NaN     525011903
# 1                         Oxtr-T2A-Cre     565871768
# 2                       Pvalb-IRES-Cre     469801138
# 3                                  NaN     528642047
# 4     Slc32a1-T2A-FlpO|Vipr2-IRES2-Cre     605889373
# ...                                ...           ...
# 2328                               NaN     601958555
# 2329                    Rorb-IRES2-Cre     488473535
# 2330                    Rorb-IRES2-Cre     467003163
# 2331                    Pvalb-IRES-Cre     572609946
# 2332                      Sst-IRES-Cre     464212183
#
#                                          specimen__name specimen__hemisphere  \
# 0                                   H16.03.003.01.14.02                right
# 1                      Oxtr-2A-Cre;Ai14-293837.03.01.02                 left
# 2                   Pvalb-IRES-Cre;Ai14-170927.05.02.01                right
# ...

# %%
https://api.brain-map.org/neuronal_model/download/473863035
